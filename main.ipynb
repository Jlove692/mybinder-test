# %% [markdown]
# # Virtual Machine Workaround Lab
# This notebook simulates the virtual environment using Binder (Linux-based).
#
# ## Objective
# - Run code inside an isolated virtual environment.
# - Use a cloud-based Linux OS instead of VMware.
#
# ## Sample Python Code:

# %%
import platform
print("Running on:", platform.system(), platform.release())
